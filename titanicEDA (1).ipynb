# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.dropna( inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Has_Cabin      0
# dtype: int64

# %%
#to detect outliers we create boxplot

# %%
plt.figure()
sns.boxplot(x=df['Fare'])
plt.title("Boxplot of Fare")
plt.show()

# %%
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Cap outliers
df['Fare'] = np.where(df['Fare'] > upper, upper, df['Fare'])

# %% [markdown]
# # univariate analysis

# %%
sns.countplot( x= 'Survived' ,data=df)
plt.title('Survived Count')
plt.show()

# %%
sns.countplot(x='Pclass',data=df)
plt.title('Passanger Class Distribution')
plt.show()

# %%
sns.countplot(x='Sex', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
sns.histplot(df['Age'], bins=20,kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['Fare'], bins=20, kde=True)
plt.title("Fare Distribution")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#survival vs gender

# %%
sns.barplot(x='Sex',y='Survived',data=df)
plt.title('Survival Rate by Gender')
plt.show()

# %%
#survival vs p class

# %%
sns.barplot(x='Pclass',y='Survived',data=df)
plt.title('Survival Rate by Passager class')
plt.show()

# %%
sns.boxplot(x='Age',y='Survived',data=df)
plt.title('Survival Rate by Age')
plt.show()

# %%
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title("Fare vs Survival")
plt.show()

# %%
sns.barplot(x='Embarked', y='Survived', data=df)
plt.title("Survival Rate by Embarked Port")
plt.show()

# %%
#correlation heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot( data = df) #multivariate plot

# %%
#dis vs dis

# %%
pd.crosstab(index= df['Survived'],columns = df['Pclass'])
# Out:
# Pclass     1   2    3
# Survived
# 0         57  63  145
# 1         50  30   72

# %%
#conti vs conti - scatter plot

# %%
sns.scatterplot(x= 'Age',y='Fare',data=df)
plt.show()

# %%
plt.pie(x= df['Pclass'].value_counts(),autopct = '%1.0f%%' , labels=['1' ,' 2' ,'3'],explode = [0.02,0,0.02])
plt.show()

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# # 1. Females had significantly higher survival rate than males.
# # 2. 1st class passengers had better survival probability.
# # 3. Higher fare passengers survived more.
# # 4. Children had slightly better survival rate.
# # 5. Most passengers were from 3rd class and majority did not survive.
